# %%
from mod1 import *

now = dt.datetime.today().strftime('%Y-%m-%d')
#engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
#conn = pymysql.connect(host = 'localhost', user = 'kkang', password = 'leaf2027' ,db = 'stock')
#curs = conn.cursor()

## def get_stock_price_from_fdr(end_date=now):  코스피,코스닥 전체종목 입력  , make_date실행중 error났을때 이후분 실행
        
file_name = input('파일이름을 입력하세요: sample: new_stock.xlsx')
toward = input('저장 방식을 입력하세요 : sample: excel, sql ')
start_date = input("시작날자를 입려하세요 : sample: '2015-01-01'")
table_name = input("table명을 입력하세요 : sample: market")
data=pd.read_excel('C:/users/linux/OneDrive/stockdata/'+ file_name)
   
code_list = data['code'].tolist()
code_list = [str(item).zfill(6) for item in code_list]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              
name_list = data['name'].tolist()
#now = '2022-06-22'
# 코스피 상장종목 전체
stock_dic = dict(list(zip(code_list,name_list)))

for code in sorted(stock_dic.keys()):
    df  = fdr.DataReader(code,start_date,now)
    print(code,stock_dic[code])
    df['Code'],df['Name'] = code,stock_dic[code]
    df = df[['Code','Name','Open','High','Low','Volume','Close']]
    if toward == 'excel':
        df.to_excel('d:\\data_set\\kospi\\'+ stock_dic[code] +'.xlsx',engine = 'xlsxwriter')
    elif toward == 'sql':
        df.to_sql(name=table_name, con=engine, if_exists='append')
# Out:
# 파일이름을 입력하세요: sample: new_stock.xlsxmarket_repeat.xlsx
# 저장 방식을 입력하세요 : sample: excel, sql sql
# 시작날자를 입려하세요 : sample: '2015-01-01''2025-02-28'
# table명을 입력하세요 : sample: marketmarket
# 054800 아이디스홀딩스
# 054920 한컴위드
# 054930 유신
# 054940 엑사이엔씨
# 054950 제이브이엠
# 055490 테이팩스
# 055550 신한지주
# 056080 유진로봇
# 056090 이노시스
# 056190 에스에프에이
# 056360 코위버
# 056700 신화인터텍
# 056730 CNT85
# 057030 YBM넷
# 057050 현대홈쇼핑
# 057540 옴니시스템
# 057680 티사이언티픽
# 057880 피에이치씨
# 058110 멕아이씨에스
# 058400 KNN
# 058430 포스코스틸리온
# 058450 일야
# 058470 리노공업
# 058610 에스피지
# 058630 엠게임
# 058650 세아홀딩스
# 058730 다스코
# 058820 CMG제약
# 058850 KTcs
# 058860 KTis
# 058970 엠로
# 059090 미코
# 059100 아이컴포넌트
# 059120 아진엑스텍
# 059210 메타바이오메드
# 059270 해성티피씨
# 060150 인선이엔티
# 060230 소니드
# 060240 룽투코리아
# 060250 NHN KCP
# 060260 뉴보텍
# 060280 큐렉소
# 060310 3S
# 060370 KT서브마린
# 060380 동양에스텍
# 060480 국일신동
# 060540 에스에이티
# 060560 홈센타홀딩스
# 060570 드림어스컴퍼니
# 060590 씨티씨바이오
# 060720 KH바텍
# 060850 영림원소프트랩
# 060900 DGP
# 060980 HL홀딩스
# 061040 알에프텍
# 061250 화일약품
# ...

# %% [markdown]
# import mod1

# %% [raw]
# from mod1 import *

# %%
import  mod1 
a = mod1.to_excel()

# %%
a.get_program_trend_date(choice=2)
# Out:
# 444
# 444
# Empty DataFrame
# Columns: [차익, 비차익, 전체]
# Index: []

# %%
a.get_investor_trend_date(choice=2)
# Out:
# 431
# 431
# Empty DataFrame
# Columns: [개인, 외국인, 기관]
# Index: []

# %%
a.get_kpi200_date(choice=2)
# Out:
# 788
# 788
#             KPI200     거래량
# 2025-02-28  334.27  238354

# %%
a.get_money_trend_date(choice=2)
# Out:
# 282
# 282
#            고객예탁금    신용잔고    주식형펀드   혼합형펀드    채권형펀드
# 25-02-26  544946  179559  1343927  294439  1866728

# %%
import mod1
import pymysql
import sqlalchemy
from pykrx import stock

# %%
b = mod1.to_sql()

# %%
b.excel_to_sql(choice=2)
# Out:
# kpi200
#          Date  KPI200     거래량
# 0  2025-02-28  334.27  238354
# investortrend
# Empty DataFrame
# Columns: [Date, 개인, 외국인, 기관]
# Index: []
# moneytrend
#        Date   고객예탁금    신용잔고    주식형펀드   혼합형펀드    채권형펀드
# 0  25-02-26  544946  179559  1343927  294439  1866728
# programtrend
# Empty DataFrame
# Columns: [Date, 차익, 비차익, 전체]
# Index: []
# kospi_sector
#           date sectorName  changeRate    first       second
# 0   2024-05-16         보험    5.077477     삼성화재        삼성화재우
# 1   2024-05-16        금융업    1.750417     삼성화재        삼성화재우
# 2   2024-05-16         기계    1.486922  다이나믹디자인         두산밥캣
# 3   2024-05-16    코스피 중형주    1.305298   이수페타시스  LS ELECTRIC
# 4   2024-05-16      비금속광물    1.223299    한일시멘트       아세아시멘트
# 5   2024-05-16      철강및금속    1.039082       서원         고려아연
# 6   2024-05-16        의약품    0.924821     유유제약         유한양행
# 7   2024-05-16      전기,전자    0.872077   이수페타시스  LS ELECTRIC
# 8   2024-05-16         증권    0.856981   한화투자증권      한화투자증권우
# ...

# %%
import kkkk

# %%
from mod1 import *
from pykrx.stock import get_index_ohlcv_by_date
def kospi_kosdaq(start_date='20240101', lastday='20251231', market='1001'):
    if market == '1001':
        df = get_index_ohlcv_by_date(start_date, lastday, market)
        if df is not None and not df.empty:
            df.index.names = ['Date']
            df.columns = ['코스피','시가', '고가', '저가', '종가', '거래량', '거래대금']
            df = df.rename(columns={
                '코스피':'Market',
                '시가': 'Open',
                '고가': 'High',
                '저가': 'Low',
                '종가': 'Close',
                '거래량': 'Volume',
                '거래대금': 'Money'
            })
            df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
            df['Market'] = 'kospi'
            df.to_sql(name='kospi', con=engine, if_exists='append')
    elif market == '2001':
        df = get_index_ohlcv_by_date(start_date, lastday, market)
        if df is not None and not df.empty:
            df.index.names = ['Date']
            df.columns = ['코스닥','시가', '고가', '저가', '종가', '거래량', '거래대금']
            df = df.rename(columns={
                '코스피':'Market',
                '시가': 'Open',
                '고가': 'High',
                '저가': 'Low',
                '종가': 'Close',
                '거래량': 'Volume',
                '거래대금': 'Money'
            })
            df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
            df['Market'] = 'kosdaq'
            df.to_sql(name='kosdaq', con=engine, if_exists='append')
# 함수 실행
kospi_kosdaq(start_date='20241023', lastday='20251231', market='1001')

# %%
def kospi_kosdaq(lastday='20251231', market='1001'):
    if market == '1001':
        df = get_index_ohlcv_by_date(kospi_next_day_no_hypyen, lastday, market)
        df.index.names = ['Date']
        df = df.iloc[:,[0,1,2,3,4]]
        df.columns  = ['Open','High','Low','Close','Volume']
        df['Market']='kospi'
        df.to_sql(name='kospi', con=engine, if_exists='append')
    elif market == '2001':
        df = get_index_ohlcv_by_date(kospi_next_day_no_hypyen, lastday, market)
        df.index.names = ['Date']
        df = df.iloc[:,[0,1,2,3,4]]
        df.columns  = ['Open','High','Low','Close','Volume']        
        df['Market']='kosdaq'
        df.to_sql(name='kosdaq', con=engine, if_exists='append')
kospi_kosdaq( market='1001')

# %%
# pykrx의 stock 모듈에서 get_index_ohlcv_by_date 함수를 명시적으로 import
from pykrx.stock import get_index_ohlcv_by_date

def kospi_kosdaq(lastday='20251231', market='1001'):
    if market == '1001':
        df = get_index_ohlcv_by_date(kospi_next_day_no_hypyen, lastday, market)
        df.index.names = ['Date']
        df = df.iloc[:,[0,1,2,3,4]]
        df.columns  = ['Open','High','Low','Close','Volume']
        df['Market']='kospi'
        df.to_sql(name='kospi', con=engine, if_exists='append')
    elif market == '2001':
        df = get_index_ohlcv_by_date(kospi_next_day_no_hypyen, lastday, market)
        df.index.names = ['Date']
        df = df.iloc[:,[0,1,2,3,4]]
        df.columns  = ['Open','High','Low','Close','Volume']        
        df['Market']='kosdaq'
        df.to_sql(name='kosdaq', con=engine, if_exists='append')

#kospi_kosdaq( market='1001')
kospi_next_day_no_hypyen = '2024123'  # 시작날짜 설정
kospi_kosdaq(lastday='20251231', market='1001')

# %%
from mod1 import *
from pykrx.stock import get_index_ohlcv_by_date
def kospi_kosdaq(start_date='20240101', lastday='20251231', market='1001'):
    if market == '1001':
        df = get_index_ohlcv_by_date(start_date, lastday, market)
        if df is not None and not df.empty:
            df.index.names = ['Date']
            df.columns = ['코스피','시가', '고가', '저가', '종가', '거래량', '거래대금']
            df = df.rename(columns={
                '코스피':'Market',
                '시가': 'Open',
                '고가': 'High',
                '저가': 'Low',
                '종가': 'Close',
                '거래량': 'Volume',
                '거래대금': 'Money'
            })
            df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
            df['Market'] = 'kospi'
            df.to_sql(name='kospi', con=engine, if_exists='append')
    elif market == '2001':
        df = get_index_ohlcv_by_date(start_date, lastday, market)
        if df is not None and not df.empty:
            df.index.names = ['Date']
            df.columns = ['코스닥','시가', '고가', '저가', '종가', '거래량', '거래대금']
            df = df.rename(columns={
                '코스피':'Market',
                '시가': 'Open',
                '고가': 'High',
                '저가': 'Low',
                '종가': 'Close',
                '거래량': 'Volume',
                '거래대금': 'Money'
            })
            df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
            df['Market'] = 'kosdaq'
            df.to_sql(name='kosdaq', con=engine, if_exists='append')
# 함수 실행
kospi_kosdaq(start_date='20250223', lastday='20251231', market='1001')

# 함수 실행
#kospi_kosdaq(start_date='20250123', lastday='20251231', market='1001')

# %%
from pykrx.stock import get_index_ohlcv_by_date
def kospi_kosdaq(start_date='20240101', lastday='20251231', market='1001'):
    if market == '1001':
        df = get_index_ohlcv_by_date(start_date, lastday, market)
        if df is not None and not df.empty:
            df.index.names = ['Date']
            print(df)
    elif market == '2001':
        # ... similar code for KOSDAQ ...
        pass

# 함수 실행
kospi_kosdaq(start_date='20241023', lastday='20251231', market='1001')

# %% [markdown]
# ###
